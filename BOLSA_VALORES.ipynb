# %% [markdown]
# <a href="https://colab.research.google.com/github/GPellizzaro/pl/blob/master/BOLSA_VALORES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar as bibliotecas necessárias
import pandas as pd
from pandas_datareader import data as web
import plotly.graph_objects as go
 
# criar um DataFrame vazio
df = pd.DataFrame()

# escolher a ação desejada
acao = 'ITUB4.SA'
 
# importar dados para o DataFrame
df = web.DataReader(acao, data_source='yahoo', start='04-01-2020')
 
# ver as 5 primeiras entradas
df.head(30)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2020-04-01  22.379999  21.190001  22.219999  21.400000  44343800.0  21.385902
# 2020-04-02  22.000000  21.150000  21.379999  21.500000  39156300.0  21.485836
# 2020-04-03  21.480000  20.010000  21.420000  20.660000  37393100.0  20.646391
# 2020-04-06  22.680000  21.889999  22.139999  22.180000  39305700.0  22.165390
# 2020-04-07  23.879999  22.920000  23.500000  23.000000  38049700.0  22.984848
# 2020-04-08  24.389999  22.940001  23.010000  24.180000  40947000.0  24.164072
# 2020-04-09  24.700001  23.500000  24.459999  23.500000  37307000.0  23.484520
# 2020-04-13  24.000000  23.020000  23.450001  24.000000  21602700.0  23.984190
# 2020-04-14  25.150000  24.299999  24.459999  24.299999  33766100.0  24.283991
# 2020-04-15  24.480000  23.370001  23.850000  23.400000  34845100.0  23.384584
# 2020-04-16  23.820000  22.799999  23.700001  22.809999  31071300.0  22.794973
# ...

# %%
# plotar o gráfico de candlestick
trace1 = {
    'x': df.index,
    'open': df.Open,
    'close': df.Close,
    'high': df.High,
    'low': df.Low,
    'type': 'candlestick',
    'name': acao,
    'showlegend': False
}
 
data = [trace1]
layout = go.Layout()
 
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="de2fe93c-0618-48cb-98f0-a509a41f57f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("de2fe93c-0618-48cb-98f0-a509a41f57f0")) {
#                     Plotly.newPlot(
#                         'de2fe93c-0618-48cb-98f0-a509a41f57f0',
# ...

# %%
# importar as bibliotecas necessárias
import pandas as pd
from pandas_datareader import data as web
import plotly.graph_objects as go
 
# criar um DataFrame vazio
df = pd.DataFrame()

# escolher a ação desejada
acao = 'ABEV3.SA'
 
# importar dados para o DataFrame
df = web.DataReader(acao, data_source='yahoo', start='04-01-2020')
 
# ver as 5 primeiras entradas
df.head(30)
# Out:
#              High    Low   Open  Close    Volume  Adj Close
# Date
# 2020-04-01  11.92  11.44  11.60  11.69  25192600      11.69
# 2020-04-02  12.24  11.47  11.68  11.99  18013700      11.99
# 2020-04-03  11.94  11.16  11.94  11.39  22886300      11.39
# 2020-04-06  12.57  11.68  12.00  11.86  19126100      11.86
# 2020-04-07  12.97  12.30  12.65  12.41  37535900      12.41
# 2020-04-08  12.68  12.02  12.50  12.31  22934300      12.31
# 2020-04-09  12.72  12.10  12.51  12.10  23748200      12.10
# 2020-04-13  12.24  11.90  12.11  12.10  17076200      12.10
# 2020-04-14  12.59  12.09  12.29  12.09  21281900      12.09
# 2020-04-15  12.06  11.72  11.92  11.91  35812700      11.91
# 2020-04-16  12.02  11.40  11.96  11.45  26018500      11.45
# 2020-04-17  11.80  11.49  11.70  11.60  16763000      11.60
# 2020-04-20  11.85  11.29  11.40  11.61  22065800      11.61
# 2020-04-22  11.79  11.51  11.65  11.62  22788300      11.62
# 2020-04-23  11.84  11.44  11.73  11.55  23608700      11.55
# ...

# %%
# plotar o gráfico de candlestick
trace1 = {
    'x': df.index,
    'open': df.Open,
    'close': df.Close,
    'high': df.High,
    'low': df.Low,
    'type': 'candlestick',
    'name': acao,
    'showlegend': False
}
 
data = [trace1]
layout = go.Layout()
 
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="67e2ad32-cc50-4b51-8060-5028ace5c25d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("67e2ad32-cc50-4b51-8060-5028ace5c25d")) {
#                     Plotly.newPlot(
#                         '67e2ad32-cc50-4b51-8060-5028ace5c25d',
# ...

# %%
# importar as bibliotecas necessárias
import pandas as pd
from pandas_datareader import data as web
import plotly.graph_objects as go
 
# criar um DataFrame vazio
df = pd.DataFrame()

# escolher a ação desejada
acao = 'MOVI3.SA'
 
# importar dados para o DataFrame
df = web.DataReader(acao, data_source='yahoo', start='04-01-2020')
 
# ver as 5 primeiras entradas
df.head(30)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
#              High    Low   Open  Close   Volume  Adj Close
# Date
# 2020-04-01   8.23   7.40   7.83   7.88  5728300       7.88
# 2020-04-02   8.13   7.52   8.01   7.80  7169100       7.80
# 2020-04-03   7.86   7.07   7.85   7.79  5051000       7.79
# 2020-04-06   9.14   7.97   8.19   8.62  5978400       8.62
# 2020-04-07   9.62   8.81   9.30   8.95  5448000       8.95
# 2020-04-08  10.21   8.81   8.95   9.71  4178800       9.71
# 2020-04-09  10.29   9.56  10.00   9.86  3520700       9.86
# 2020-04-13  10.00   9.41   9.80   9.65  2816200       9.65
# 2020-04-14  10.19   9.72   9.84   9.92  3351600       9.92
# 2020-04-15  10.47   9.46   9.65   9.97  3545100       9.97
# 2020-04-16  10.40   9.75  10.20   9.92  2971200       9.92
# ...

# %%
# plotar o gráfico de candlestick
trace1 = {
    'x': df.index,
    'open': df.Open,
    'close': df.Close,
    'high': df.High,
    'low': df.Low,
    'type': 'candlestick',
    'name': acao,
    'showlegend': False
}
 
data = [trace1]
layout = go.Layout()
 
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="294756cb-6bd3-4097-9984-8797dc483e0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("294756cb-6bd3-4097-9984-8797dc483e0a")) {
#                     Plotly.newPlot(
#                         '294756cb-6bd3-4097-9984-8797dc483e0a',
# ...
